# %%
using JLD2, Plots, Plots.Measures, VeryDiff, VeryDiffPolyExperiments, VNNLib, DataFrames

# %% [markdown]
# # MNIST
#
# According to prior literature, we focus on networks trained with high L1 regularization.

# %%
mnist_relu_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_256x4_1e4_results_2026-04-21T22:24:36.821.jld2")
mnist_relu_results = load(mnist_relu_result_path)["result_dict"]
mnist_relu_results["activation"] = "ReLU"
mnist_relu_results["n_polys_per_layer"] = Inf 
mnist_relu_results["bound_method"] = "aCROWN"
mnist_relu_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[17.2002, 4.12251, 8.89904, 30.8489, 44.7559]
#   "n_polys_per_layer"   => Inf
#   "mse_polys"           => Any[0.984317, 0.986017, 0.986267, 0.986433, 0.98645]
#   "ϵs"                  => Any[18.1687, 8.88155, 5.87421, 4.37919, 3.49688]
#   "t_evals"             => Any[18.6809, 22.8189, 26.4766, 35.0886, 36.3767]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "aCROWN"
#   "activation"          => "ReLU"
#   "ϵ_samples"           => Any[2.94096, 1.65403, 0.912949, 0.613761, 0.523158]
#   "t_approxs"           => Any[7.75697, 9.34767, 15.2641, 44.2736, 64.6644]

# %%
mnist_gelu_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_gelu_256x4_1e4_results_2026-04-21T22:31:54.056.jld2")
mnist_gelu_results = load(mnist_gelu_result_path)["result_dict"]
mnist_gelu_results["activation"] = "GELU"
mnist_gelu_results["n_polys_per_layer"] = Inf 
mnist_gelu_results["bound_method"] = "aCROWN"
mnist_gelu_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[0.701208, 1.18686, 3.04947, 6.41261, 10.0343]
#   "n_polys_per_layer"   => Inf
#   "mse_polys"           => Any[0.988733, 0.98925, 0.989267, 0.9893, 0.9893]
#   "ϵs"                  => Any[5.55205, 0.514039, 0.070915, 0.0116909, 0.001853…
#   "t_evals"             => Any[22.0021, 23.6766, 29.0332, 32.7648, 38.0004]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "aCROWN"
#   "activation"          => "GELU"
#   "ϵ_samples"           => Any[2.16107, 0.292207, 0.0533147, 0.0108318, 0.00179…
#   "t_approxs"           => Any[18.4168, 23.1129, 28.7379, 46.5521, 59.4232]

# %%
mnist_relu_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_256x4_1e4_results_2026-04-22T11:04:36.804.jld2")
mnist_relu_single_results = load(mnist_relu_single_result_path)["result_dict"]
mnist_relu_single_results["activation"] = "ReLU"
mnist_relu_single_results["n_polys_per_layer"] = 1
mnist_relu_single_results["bound_method"] = "aCROWN"
mnist_relu_single_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[19.8147, 3.27201, 6.86373, 26.5072, 40.148]
#   "n_polys_per_layer"   => 1
#   "mse_polys"           => Any[0.978267, 0.984983, 0.985467, 0.98615, 0.986067]
#   "ϵs"                  => Any[1054.22, 1029.52, 1021.43, 1016.67, 1014.86]
#   "t_evals"             => Any[21.0792, 25.1993, 29.1454, 31.7387, 34.9949]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "aCROWN"
#   "activation"          => "ReLU"
#   "ϵ_samples"           => Any[7.26277, 3.27196, 1.77635, 1.61823, 1.19581]
#   "t_approxs"           => Any[6.65531, 4.01643, 4.02527, 4.16003, 4.2215]

# %%
# from different computer !!!
mnist_relu_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_256x4_1e4_results_2026-04-27T16:49:01.520.jld2")
mnist_relu_zono_results = load(mnist_relu_zono_result_path)["result_dict"]
mnist_relu_zono_results["activation"] = "ReLU"
mnist_relu_zono_results["n_polys_per_layer"] = Inf 
mnist_relu_zono_results["bound_method"] = "zono"
mnist_relu_zono_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[0.861393, 3.5349, 7.17983, 23.5568, 34.6748]
#   "n_polys_per_layer"   => Inf
#   "mse_polys"           => Any[0.982667, 0.984933, 0.9856, 0.986117, 0.986167]
#   "ϵs"                  => Any[22.0377, 10.9164, 7.23983, 5.40765, 4.32083]
#   "t_evals"             => Any[15.994, 23.2935, 21.6493, 25.1848, 28.7527]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 1, 1}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "zono"
#   "activation"          => "ReLU"
#   "ϵ_samples"           => Any[5.44755, 2.23402, 1.44049, 1.12606, 0.903436]
#   "t_approxs"           => Any[1.1783, 4.77431, 11.8183, 40.3332, 60.3508]

# %%
# from different computer !!!
mnist_gelu_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_gelu_256x4_1e4_results_2026-04-27T16:54:40.987.jld2")
mnist_gelu_zono_results = load(mnist_gelu_zono_result_path)["result_dict"]
mnist_gelu_zono_results["activation"] = "GELU"
mnist_gelu_zono_results["n_polys_per_layer"] = Inf 
mnist_gelu_zono_results["bound_method"] = "zono"
mnist_gelu_zono_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[4.04228, 1.02941, 2.97792, 5.34481, 9.07005]
#   "n_polys_per_layer"   => Inf
#   "mse_polys"           => Any[0.987133, 0.98875, 0.989117, 0.98925, 0.989317]
#   "ϵs"                  => Any[11.9499, 2.97711, 1.06663, 0.434929, 0.181335]
#   "t_evals"             => Any[15.1597, 19.814, 22.1876, 27.5149, 27.6843]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 1, 1}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "zono"
#   "activation"          => "GELU"
#   "ϵ_samples"           => Any[5.29702, 1.83317, 0.728914, 0.299098, 0.132848]
#   "t_approxs"           => Any[5.37552, 7.98579, 16.7054, 48.2348, 68.8134]

# %%
mnist_gelu_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_gelu_256x4_1e4_results_2026-04-22T11:09:50.027.jld2")
mnist_gelu_single_results = load(mnist_gelu_single_result_path)["result_dict"]
mnist_gelu_single_results["activation"] = "GELU"
mnist_gelu_single_results["n_polys_per_layer"] = 1
mnist_gelu_single_results["bound_method"] = "aCROWN"
mnist_gelu_single_results
# Out:
# Dict{String, Any} with 13 entries:
#   "degrees"             => 20:20:100
#   "t_verifies"          => Any[1.30331, 1.55387, 3.84348, 8.8432, 14.311]
#   "n_polys_per_layer"   => 1
#   "mse_polys"           => Any[0.984967, 0.988383, 0.989133, 0.9893, 0.9893]
#   "ϵs"                  => Any[19.6055, 3.2147, 0.632444, 0.136381, 0.0339556]
#   "t_evals"             => Any[19.3917, 25.4607, 28.4713, 32.2142, 37.7422]
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["/flatten/Flatten"], ["/f…
#   "approx_poly_threads" => 1
#   "bound_method"        => "aCROWN"
#   "activation"          => "GELU"
#   "ϵ_samples"           => Any[4.96101, 1.2656, 0.319428, 0.0851029, 0.0240892]
#   "t_approxs"           => Any[16.8432, 16.8004, 17.1187, 18.4096, 18.9128]

# %%
mnist_relu_sampled_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_256x4_1e4_sampling_2026-04-21T22:43:47.990.jld2")
mnist_relu_sampled_networks = load(mnist_relu_sampled_path)["sampled_networks"]
# Out:
# 5-element Vector{Any}:
# ...

# %%
mnist_gelu_sampled_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "mnist", "mnist_gelu_256x4_1e4_sampling_2026-04-21T22:47:59.366.jld2")
mnist_gelu_sampled_networks = load(mnist_gelu_sampled_path)["sampled_networks"]
# Out:
# 5-element Vector{Any}:
# ...

# %% [markdown]
# ## Example for JSON Export

# %%
VeryDiffPolyExperiments.export2json(mnist_gelu_sampled_networks[end], "mnist_gelu_256x4_1e4_sampling_100.json")
# Out:
# 17527010

# %% [markdown]
# ## Plot

# %%
plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=[1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3], ylims=(1e-3, 2000), legend=:bottomleft)

plot!(mnist_relu_single_results["degrees"], mnist_relu_single_results["ϵs"], label="ReLU single (verified)", markershape=:circle, color=1)
plot!(mnist_relu_single_results["degrees"], mnist_relu_single_results["ϵ_samples"], label="ReLU single (sampled)", linestyle=:dash, markershape=:circle, color=1)

plot!(mnist_gelu_single_results["degrees"], mnist_gelu_single_results["ϵs"], label="GELU single(verified)", markershape=:circle, color=2)
plot!(mnist_gelu_single_results["degrees"], mnist_gelu_single_results["ϵ_samples"], label="GELU single(sampled)", linestyle=:dash, markershape=:circle, color=2)

plot!(mnist_relu_zono_results["degrees"], mnist_relu_zono_results["ϵs"], label="ReLU zono (verified)", markershape=:circle, color=3)
plot!(mnist_relu_zono_results["degrees"], mnist_relu_zono_results["ϵ_samples"], label="ReLU zono (sampled)", markershape=:circle, linestyle=:dash, color=3)

plot!(mnist_gelu_zono_results["degrees"], mnist_gelu_zono_results["ϵs"], label="GELU zono (verified)", markershape=:circle, color=4)
plot!(mnist_gelu_zono_results["degrees"], mnist_gelu_zono_results["ϵ_samples"], label="GELU zono (sampled)", markershape=:circle, linestyle=:dash, color=4)

plot!(mnist_relu_results["degrees"], mnist_relu_results["ϵs"], label="ReLU (verified)", markershape=:circle, color=5)
plot!(mnist_relu_results["degrees"], mnist_relu_results["ϵ_samples"], label="ReLU (sampled)", markershape=:circle, linestyle=:dash, color=5)

plot!(mnist_gelu_results["degrees"], mnist_gelu_results["ϵs"], label="GELU (verified)", markershape=:circle, color=6)
plot!(mnist_gelu_results["degrees"], mnist_gelu_results["ϵ_samples"], label="GELU (sampled)", markershape=:circle, linestyle=:dash, color=6)

# %%
p = plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=[1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3], ylims=(1e-3, 2000), xlims=(15, 105), legend=:outerright)

plot!(mnist_relu_single_results["degrees"], mnist_relu_single_results["ϵs"], label="ReLU single", markershape=:circle, color=1)
plot!(mnist_relu_single_results["degrees"], mnist_relu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=1)

plot!(mnist_gelu_single_results["degrees"], mnist_gelu_single_results["ϵs"], label="GELU single", markershape=:circle, color=2)
plot!(mnist_gelu_single_results["degrees"], mnist_gelu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=2)

plot!(mnist_relu_zono_results["degrees"], mnist_relu_zono_results["ϵs"], label="ReLU zono", markershape=:circle, color=3)
plot!(mnist_relu_zono_results["degrees"], mnist_relu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=3)

plot!(mnist_gelu_zono_results["degrees"], mnist_gelu_zono_results["ϵs"], label="GELU zono", markershape=:circle, color=4)
plot!(mnist_gelu_zono_results["degrees"], mnist_gelu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=4)

plot!(mnist_relu_results["degrees"], mnist_relu_results["ϵs"], label="ReLU", markershape=:circle, color=5)
plot!(mnist_relu_results["degrees"], mnist_relu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=5)

plot!(mnist_gelu_results["degrees"], mnist_gelu_results["ϵs"], label="GELU", markershape=:circle, color=6)
plot!(mnist_gelu_results["degrees"], mnist_gelu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=6)

plot!([0], [1], label="\n", color = :white)

plot!([0], [1], label="verified error", color = :black, linestyle=:solid)
plot!([0], [1], label="sampled error", color = :black, linestyle=:dash)

# %%
savefig(p, "../fig/gelu/ablation_mnist_256x4_1e4.pdf")
# Out:
# "/home/philipp/VerifyNN/VeryDiffPolyExperiments/analysis/fig/gelu/ablation_mnist_256x4_1e4.pdf"

# %% [markdown]
# ## Statistics

# %%
data_list = [mnist_relu_results, mnist_gelu_results,
             mnist_relu_single_results, mnist_gelu_single_results,
             mnist_relu_zono_results, mnist_gelu_zono_results]
df = DataFrame(data_list)
select!(df, Not(:networks))
df = flatten(df, [:t_evals, :degrees, :t_approxs, :t_verifies, :mse_polys, :ϵ_samples, :ϵs])
df = rename(df, :t_verifies => :t_verify, :t_approxs => :t_approx, :t_evals => :t_eval, :mse_polys => :mse_poly, :ϵ_samples => :ϵ_sample, :ϵs => :ϵ)
# Out:
# 30×12 DataFrame
#  Row │ degrees  t_verify  n_polys_per_layer  mse_poly  ϵ         t_eval   thre ⋯
#      │ Int64    Any       Float64            Any       Any       Any      Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │      20  17.2002                 Inf  0.984317  18.1687   18.6809       ⋯
#    2 │      40  4.12251                 Inf  0.986017  8.88155   22.8189
#    3 │      60  8.89904                 Inf  0.986267  5.87421   26.4766
#    4 │      80  30.8489                 Inf  0.986433  4.37919   35.0886
#    5 │     100  44.7559                 Inf  0.98645   3.49688   36.3767       ⋯
#    6 │      20  0.701208                Inf  0.988733  5.55205   22.0021
#    7 │      40  1.18686                 Inf  0.98925   0.514039  23.6766
#    8 │      60  3.04947                 Inf  0.989267  0.070915  29.0332
#   ⋮  │    ⋮        ⋮              ⋮             ⋮         ⋮         ⋮        ⋮ ⋱
# ...

# %%
df_relu = df[df.activation .== "ReLU", :]
df_gelu = df[df.activation .== "GELU", :]

df_relu[:, :ϵ]
# Out:
# 15-element Vector{Any}:
#    18.16870975706247
#     8.881546993199875
#     5.874212426237012
#     4.379190383256675
#     3.496880115705387
#  1054.2235196187517
#  1029.5200791559837
#  1021.4345994253249
#  1016.6660048959859
#  1014.8559161915631
#    22.037695459256042
#    10.916361305227523
#     7.23983448608511
#     5.407654357301758
#     4.320829408445667

# %%
println("relu single vs multiple: ", mnist_relu_single_results["ϵs"] ./ mnist_relu_results["ϵs"])
println("gelu single vs multiple: ", mnist_gelu_single_results["ϵs"] ./ mnist_gelu_results["ϵs"])
# Out:
# relu single vs multiple: [58.02412684857592, 115.91675188390403, 173.88451852083435, 232.1584393277557, 290.21753180315915]
# gelu single vs multiple: [3.5312189943998606, 6.253801832893147, 8.91834623544097, 11.665556395152885, 18.314858744476957]

# %%
println("relu zono vs aCROWN: ", mnist_relu_zono_results["ϵs"] ./ mnist_relu_results["ϵs"])
println("gelu zono vs aCROWN: ", mnist_gelu_zono_results["ϵs"] ./ mnist_gelu_results["ϵs"])
# Out:
# relu zono vs aCROWN: [1.2129477411399363, 1.2291058431133222, 1.2324774728521195, 1.234852537578018, 1.2356241179214902]
# gelu zono vs aCROWN: [2.1523318121345185, 5.791595737828886, 15.040918465975945, 37.202287730057535, 97.8080104612929]

# %%
println("relu vs gelu: ", mnist_relu_results["ϵs"] ./ mnist_gelu_results["ϵs"])
# Out:
# relu vs gelu: [3.2724329770240685, 17.277956080036216, 82.83460919477027, 374.58020044654796, 1886.133745048851]

# %% [markdown]
# # Collins RUL

# %%
collins_gelu_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_gelu_1e-3l1_kernel_size_results_2026-04-23T08:59:14.344.jld2")
collins_gelu_single_results = load(collins_gelu_single_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[19.0275, 20.6208, 22.9202, 24.8728, 26.8577, 29.…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[605.637, 600.077, 570.045, 572.027, 567.884, 526…
#   "t_verifies"          => Any[15.2688, 14.0358, 23.5285, 56.892, 89.9259, 125.…
#   "mse_polys"           => Any[602.284, 601.496, 569.933, 579.445, 525.052, 530…
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[55.154, 29.1827, 22.3416, 10.6953, 6.16439, 3.82…
#   "ϵs"                  => Any[5493.77, 1237.82, 423.281, 167.765, 81.5991, 41.…

# %%
collins_gelu_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_gelu_1e-3l1_kernel_size_results_2026-04-23T10:32:15.534.jld2")
collins_gelu_results = load(collins_gelu_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[18.2464, 20.6253, 23.1211, 25.1296, 26.944, 29.1…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[549.335, 578.711, 603.093, 778.012, 870.927, 986…
#   "t_verifies"          => Any[14.8834, 14.9483, 25.2601, 70.9579, 108.038, 159…
#   "mse_polys"           => Any[629.604, 550.951, 522.925, 532.614, 528.498, 528…
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[20.8874, 6.36808, 3.7711, 2.37107, 1.62673, 1.37…
#   "ϵs"                  => Any[58.518, 13.6346, 7.92761, 5.87445, 4.66307, 3.83…

# %%
collins_gelu_full_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_gelu_1e-3l1_kernel_size_results_2026-04-23T12:47:05.795.jld2")
collins_gelu_full_single_results = load(collins_gelu_full_single_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[62.4365, 67.6438, 71.4213, 75.7164, 79.4987, 83.…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[3076.61, 3070.12, 3028.21, 3083.59, 3031.93, 293…
#   "t_verifies"          => Any[41.1815, 48.3735, 61.8689, 130.458, 181.962, 262…
#   "mse_polys"           => Any[7279.79, 1907.15, 928.329, 690.842, 699.223, 689…
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[193.767, 62.6847, 36.8084, 17.6446, 10.8786, 7.9…
#   "ϵs"                  => Any[10030.5, 1413.5, 406.542, 177.21, 91.5017, 49.34…

# %%
collins_gelu_full_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_gelu_1e-3l1_kernel_size_results_2026-04-22T17:10:12.909.jld2")
collins_gelu_full_results = load(collins_gelu_full_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[63.3382, 67.2415, 71.9172, 74.6179, 79.1002, 82.…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[3082.29, 3036.41, 3198.62, 3523.95, 3852.1, 4136…
#   "t_verifies"          => Any[45.2597, 48.384, 63.5403, 144.236, 211.082, 301.…
#   "mse_polys"           => Any[2729.7, 725.898, 682.39, 712.101, 695.93, 687.02…
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[71.7033, 21.7168, 15.3702, 7.94666, 7.26922, 4.4…
#   "ϵs"                  => Any[308.762, 81.8151, 36.0607, 20.3317, 12.9537, 9.1…

# %%
collins_gelu_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_gelu_1e-3l1_kernel_size_results_2026-04-30T11:31:39.617.jld2")
collins_gelu_zono_results = load(collins_gelu_zono_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[18.3699, 20.9817, 23.212, 25.1333, 27.2159, 29.3…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[35.8474, 47.2308, 96.7081, 273.775, 402.831, 578…
#   "t_verifies"          => Any[10.5044, 14.9976, 25.8891, 69.368, 105.506, 155.…
#   "mse_polys"           => Any[1273.33, 548.776, 546.055, 523.756, 528.47, 531.…
#   "networks"            => Any[OnnxNet{String, 1, 1}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[41.5441, 10.7784, 5.4368, 3.94907, 2.74407, 2.03…
#   "ϵs"                  => Any[136.347, 33.4602, 13.8768, 8.77668, 6.76362, 5.5…

# %%
collins_relu_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_1e-3l1_kernel_size_results_2026-04-30T12:46:59.083.jld2")
collins_relu_zono_results = load(collins_relu_zono_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 10 entries:
#   "t_evals"             => Any[18.2726, 20.8256, 23.1791, 25.0842, 27.2007, 29.…
#   "degrees"             => 20:20:160
#   "t_approxs"           => Any[9.29249, 19.5465, 47.7127, 170.24, 250.961, 375.…
#   "t_verifies"          => Any[28.4703, 16.0394, 29.3968, 92.8669, 139.485, 202…
#   "mse_polys"           => Any[722.531, 471.467, 456.293, 482.215, 461.32, 469.…
#   "networks"            => Any[OnnxNet{String, 1, 1}(["node_conv2d"], ["node_vi…
#   "threads"             => 1
#   "approx_poly_threads" => 1
#   "ϵ_samples"           => Any[31.7352, 14.0327, 6.9308, 6.88978, 3.17659, 5.18…
#   "ϵs"                  => Any[294.428, 144.771, 95.661, 71.5349, 57.1356, 47.5…

# %%
collins_gelu_full_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_gelu_1e-3l1_kernel_size_results_2026-05-02T23:51:22.432.jld2")
collins_gelu_full_zono_results = load(collins_gelu_full_zono_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :zono
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[41.3745, 49.8288, 66.5208, 142.827, 205.863, 295…
#   "mse_polys"           => Any[5296.2, 1994.14, 861.394, 708.322, 686.391, 689.…
#   "ϵ_samples"           => Any[132.731, 57.7375, 31.5569, 20.4347, 18.8886, 13.…
#   "ϵs"                  => Any[565.95, 191.264, 92.6533, 55.774, 38.1326, 27.64…
#   "t_evals"             => Any[62.5686, 66.6003, 70.868, 74.6218, 78.4115, 82.2…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 1, 1}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => Inf
#   "t_approxs"           => Any[50.0874, 88.1102, 184.625, 553.01, 844.154, 1255…
#   "approx_poly_threads" => 1

# %%
collins_relu_full_zono_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_1e-3l1_kernel_size_results_2026-05-03T02:30:16.550.jld2")
collins_relu_full_zono_results = load(collins_relu_full_zono_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :zono
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[45.212, 54.4823, 84.7873, 239.605, 351.099, 503.…
#   "mse_polys"           => Any[757.83, 575.524, 552.468, 533.369, 521.956, 501.…
#   "ϵ_samples"           => Any[32.5469, 13.797, 11.4003, 5.31022, 3.89153, 4.14…
#   "ϵs"                  => Any[501.119, 246.808, 163.479, 122.11, 97.7479, 81.2…
#   "t_evals"             => Any[61.5046, 67.2077, 71.5413, 75.2479, 79.1734, 83.…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 1, 1}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => Inf
#   "t_approxs"           => Any[18.5692, 51.744, 110.717, 403.941, 605.821, 877.…
#   "approx_poly_threads" => 1

# %%
collins_relu_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_1e-3l1_kernel_size_results_2026-05-02T22:16:09.614.jld2")
collins_relu_single_results = load(collins_relu_single_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :acrown
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[32.0373, 19.6357, 37.6337, 127.593, 199.383, 293…
#   "mse_polys"           => Any[4234.42, 1050.22, 719.206, 594.561, 627.012, 470…
#   "ϵ_samples"           => Any[122.165, 42.3523, 32.4032, 25.3107, 23.865, 15.3…
#   "ϵs"                  => Any[74807.1, 74575.2, 74243.8, 74154.7, 74046.2, 740…
#   "t_evals"             => Any[18.7933, 21.107, 23.46, 24.6164, 26.7903, 28.982…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => 1
#   "t_approxs"           => Any[47.2018, 41.1574, 40.407, 41.6946, 37.9811, 38.8…
#   "approx_poly_threads" => 1

# %%
collins_relu_full_single_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_1e-3l1_kernel_size_results_2026-05-03T05:02:05.192.jld2")
collins_relu_full_single_results = load(collins_relu_full_single_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :acrown
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[39.8008, 57.3635, 92.7266, 256.96, 408.753, 609.…
#   "mse_polys"           => Any[2857.74, 1092.48, 813.541, 744.359, 762.709, 655…
#   "ϵ_samples"           => Any[129.094, 56.865, 29.6434, 21.8713, 22.2112, 16.6…
#   "ϵs"                  => Any[1.12731e5, 1.11661e5, 1.11014e5, 1.1079e5, 1.106…
#   "t_evals"             => Any[61.3556, 66.4688, 70.5673, 74.3219, 78.0779, 82.…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => 1
#   "t_approxs"           => Any[122.802, 134.252, 133.065, 134.535, 132.598, 134…
#   "approx_poly_threads" => 1

# %%
collins_relu_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_small_window_20_1e-3l1_kernel_size_results_2026-05-02T22:55:12.321.jld2")
collins_relu_results = load(collins_relu_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :acrown
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[15.7491, 14.7914, 27.5932, 88.413, 132.927, 194.…
#   "mse_polys"           => Any[597.908, 482.171, 454.521, 457.661, 455.675, 457…
#   "ϵ_samples"           => Any[24.1798, 9.09165, 4.33622, 3.94073, 2.69661, 3.1…
#   "ϵs"                  => Any[250.724, 121.71, 81.2618, 60.4926, 48.276, 40.08…
#   "t_evals"             => Any[18.2882, 20.4485, 22.9519, 25.3962, 26.8737, 28.…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => Inf
#   "t_approxs"           => Any[57.1741, 51.7989, 70.664, 161.844, 228.09, 306.6…
#   "approx_poly_threads" => 1

# %%
collins_relu_full_result_path = joinpath(@__DIR__, "..", "..", "results", "gelu", "collins", "NN_rul_window_20_1e-3l1_kernel_size_results_2026-05-03T06:31:08.509.jld2")
collins_relu_full_results = load(collins_relu_full_result_path)["result_dict"]
# Out:
# Dict{String, Any} with 12 entries:
#   "method"              => :acrown
#   "degrees"             => 20:20:160
#   "t_verifies"          => Any[38.3142, 54.1088, 84.0956, 239.229, 349.328, 498…
#   "mse_polys"           => Any[759.164, 581.132, 520.804, 517.849, 514.939, 517…
#   "ϵ_samples"           => Any[28.9118, 12.7478, 5.11556, 4.02524, 3.10359, 2.1…
#   "ϵs"                  => Any[431.766, 209.48, 138.256, 103.058, 82.4673, 68.4…
#   "t_evals"             => Any[62.4235, 66.7157, 70.8734, 74.6494, 78.4259, 82.…
#   "threads"             => 1
#   "networks"            => Any[OnnxNet{String, 4, 2}(["node_conv2d"], ["node_vi…
#   "max_polys_per_layer" => Inf
#   "t_approxs"           => Any[137.443, 164.701, 216.097, 438.634, 594.54, 799.…
#   "approx_poly_threads" => 1

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Approximation Error

# %%
yticks = [1,2,5,10,20,50,100, 200, 500, 1000, 2000, 5000]
ytick_labels = string.(yticks)
p = plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=(yticks, ytick_labels), formatter=:plain, legend=:topright)

plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵs"], label="GELU single (verified)", markershape=:circle, color=1)
plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵ_samples"], label="GELU single (sampled)", linestyle=:dash, markershape=:circle, color=1)

plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵs"], label="GELU (verified)", markershape=:circle, color=2)
plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵ_samples"], label="GELU (sampled)", linestyle=:dash, markershape=:circle, color=2)

plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵs"], label="GELU full single (verified)", markershape=:circle, color=3)
plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵ_samples"], label="GELU full single (sampled)", linestyle=:dash, markershape=:circle, color=3)

plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵs"], label="GELU full (verified)", markershape=:circle, color=4)
plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵ_samples"], label="GELU full (sampled)", linestyle=:dash, markershape=:circle, color=4)

# %%
savefig(p, "../fig/gelu/ablation_collins.pdf")
# Out:
# "/home/philipp/VerifyNN/VeryDiffPolyExperiments/analysis/fig/gelu/ablation_collins.pdf"

# %% [markdown]
# ### All Data at Once
#
# But you cannot really see anything - so we need to split it up.

# %%
yticks = [1,2,5,10,20,50,100, 200, 500, 1000, 2000, 5000]
ytick_labels = string.(yticks)
p = plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=(yticks, ytick_labels), xlims=(15, 165), formatter=:plain, legend=:outerright)

# small networks

## single poly
plot!(collins_relu_single_results["degrees"], collins_relu_single_results["ϵs"], label="ReLU single", markershape=:circle, color=1)
plot!(collins_relu_single_results["degrees"], collins_relu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=1)

plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵs"], label="GELU single", markershape=:circle, color=2)
plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=2)

## zono bounds
plot!(collins_relu_zono_results["degrees"], collins_relu_zono_results["ϵs"], label="ReLU zono", markershape=:circle, color=3)
plot!(collins_relu_zono_results["degrees"], collins_relu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=3)

plot!(collins_gelu_zono_results["degrees"], collins_gelu_zono_results["ϵs"], label="GELU zono", markershape=:circle, color=4)
plot!(collins_gelu_zono_results["degrees"], collins_gelu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=4)

## aCROWN bounds
plot!(collins_relu_results["degrees"], collins_relu_results["ϵs"], label="ReLU", markershape=:circle, color=5)
plot!(collins_relu_results["degrees"], collins_relu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=5)

plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵs"], label="GELU", markershape=:circle, color=6)
plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=6)

# full network

## single poly
plot!(collins_relu_full_single_results["degrees"], collins_relu_full_single_results["ϵs"], label="ReLU full single", markershape=:circle, color=7)
plot!(collins_relu_full_single_results["degrees"], collins_relu_full_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=7)

plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵs"], label="GELU full single", markershape=:circle, color=8)
plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=8)

## zono bounds
plot!(collins_relu_full_zono_results["degrees"], collins_relu_full_zono_results["ϵs"], label="ReLU full zono", markershape=:circle, color=9)
plot!(collins_relu_full_zono_results["degrees"], collins_relu_full_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=9)

plot!(collins_gelu_full_zono_results["degrees"], collins_gelu_full_zono_results["ϵs"], label="GELU full zono", markershape=:circle, color=10)
plot!(collins_gelu_full_zono_results["degrees"], collins_gelu_full_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=10)

# aCROWN bounds
plot!(collins_relu_full_results["degrees"], collins_relu_full_results["ϵs"], label="ReLU full", markershape=:circle, color=11)
plot!(collins_relu_full_results["degrees"], collins_relu_full_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=11)

plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵs"], label="GELU full", markershape=:circle, color=12)
plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=12)


plot!([0], [1], label="\n", color = :white)

plot!([0], [1], label="verified error", color = :black, linestyle=:solid)
plot!([0], [1], label="sampled error", color = :black, linestyle=:dash)

# %% [markdown]
# ### Split up Small and Large NN

# %%
yticks = [1,2,5,10,20,50,100, 200, 500, 1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
ytick_labels = string.(yticks)
p1 = plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=(yticks, ytick_labels), 
          xlims=(15, 165), ylims=(0.5, 200000), formatter=:plain, legend=false,
          title="Collins RUL (small)")

# small networks

## single poly
plot!(collins_relu_single_results["degrees"], collins_relu_single_results["ϵs"], label="ReLU single", markershape=:circle, color=1)
plot!(collins_relu_single_results["degrees"], collins_relu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=1)

plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵs"], label="GELU single", markershape=:circle, color=2)
plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=2)

## zono bounds
plot!(collins_relu_zono_results["degrees"], collins_relu_zono_results["ϵs"], label="ReLU zono", markershape=:circle, color=3)
plot!(collins_relu_zono_results["degrees"], collins_relu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=3)

plot!(collins_gelu_zono_results["degrees"], collins_gelu_zono_results["ϵs"], label="GELU zono", markershape=:circle, color=4)
plot!(collins_gelu_zono_results["degrees"], collins_gelu_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=4)

## aCROWN bounds
plot!(collins_relu_results["degrees"], collins_relu_results["ϵs"], label="ReLU", markershape=:circle, color=5)
plot!(collins_relu_results["degrees"], collins_relu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=5)

plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵs"], label="GELU", markershape=:circle, color=6)
plot!(collins_gelu_results["degrees"], collins_gelu_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=6)

# legend labels
plot!([0], [1], label="\n", color = :white)

plot!([0], [1], label="verified error", color = :black, linestyle=:solid)
plot!([0], [1], label="sampled error", color = :black, linestyle=:dash)

# full network
p2 = plot(xlabel="degree", ylabel="error", yaxis=:log10, yticks=(yticks, ytick_labels), 
          xlims=(15, 165), ylims=(0.5, 200000), formatter=:plain, legend=false,
          title="Collins RUL (full)")

## single poly
plot!(collins_relu_full_single_results["degrees"], collins_relu_full_single_results["ϵs"], label="ReLU full single", markershape=:circle, color=1)
plot!(collins_relu_full_single_results["degrees"], collins_relu_full_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=1)

plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵs"], label="GELU full single", markershape=:circle, color=2)
plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=2)

## zono bounds
plot!(collins_relu_full_zono_results["degrees"], collins_relu_full_zono_results["ϵs"], label="ReLU full zono", markershape=:circle, color=3)
plot!(collins_relu_full_zono_results["degrees"], collins_relu_full_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=3)

plot!(collins_gelu_full_zono_results["degrees"], collins_gelu_full_zono_results["ϵs"], label="GELU full zono", markershape=:circle, color=4)
plot!(collins_gelu_full_zono_results["degrees"], collins_gelu_full_zono_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=4)

# aCROWN bounds
plot!(collins_relu_full_results["degrees"], collins_relu_full_results["ϵs"], label="ReLU full", markershape=:circle, color=5)
plot!(collins_relu_full_results["degrees"], collins_relu_full_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=5)

plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵs"], label="GELU full", markershape=:circle, color=6)
plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["ϵ_samples"], label=nothing, linestyle=:dash, markershape=:circle, color=6)

p3 = plot(framestyle=:none, grid=false, showaxis=false, ticks=false, legend=:inside)
plot!([0], [0], label="ReLU single", color=1)
plot!([0], [0], label="GELU single", color=2)
plot!([0], [0], label="ReLU zono", color=3)
plot!([0], [0], label="GELU zono", color=4)
plot!([0], [0], label="ReLU", color=5)
plot!([0], [0], label="GELU", color=6)

plot!([0], [1], label="\n", color = :white)

plot!([0], [1], label="verified error", color = :black, linestyle=:solid)
plot!([0], [1], label="sampled error", color = :black, linestyle=:dash)

p = plot(p1, p2, p3, layout=@layout([a b c{0.2w}]), link=:y, size=(1200, 600), left_margin=10mm, bottom_margin=10mm)

# %%
savefig(p, "../fig/gelu/ablation_collins_all.pdf")
# Out:
# "/home/philipp/VerifyNN/VeryDiffPolyExperiments/analysis/fig/gelu/ablation_collins_all.pdf"

# %% [markdown]
# ### Approximation Time

# %%
plot(xlabel="degree", ylabel="approximation time", legend=:topleft)

plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["t_approxs"], label="GELU single", markershape=:circle, color=1)
plot!(collins_gelu_results["degrees"], collins_gelu_results["t_approxs"], label="GELU", markershape=:circle, color=2)
plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["t_approxs"], label="GELU full single", markershape=:circle, color=3)
plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["t_approxs"], label="GELU full", markershape=:circle, color=4)

# %% [markdown]
# ### Verification Time

# %%
plot(xlabel="degree", ylabel="approximation time", legend=:topleft)

plot!(collins_gelu_single_results["degrees"], collins_gelu_single_results["t_verifies"], label="GELU single", markershape=:circle, color=1)
plot!(collins_gelu_results["degrees"], collins_gelu_results["t_verifies"], label="GELU", markershape=:circle, color=2)
plot!(collins_gelu_full_single_results["degrees"], collins_gelu_full_single_results["t_verifies"], label="GELU full single", markershape=:circle, color=3)
plot!(collins_gelu_full_results["degrees"], collins_gelu_full_results["t_verifies"], label="GELU full", markershape=:circle, color=4)

# %% [markdown]
# ## Statistics

# %%
# println("relu single vs multiple: ", collins_relu_single_results["ϵs"] ./ collins_relu_results["ϵs"])
println("gelu single vs multiple (small): ", collins_gelu_single_results["ϵs"] ./ collins_gelu_results["ϵs"])
println("gelu single vs multiple (full):  ", collins_gelu_full_single_results["ϵs"] ./ collins_gelu_full_results["ϵs"])
println()
println("gelu single vs multiple (small) - sampled: ", collins_gelu_single_results["ϵ_samples"] ./ collins_gelu_results["ϵ_samples"])
println("gelu single vs multiple (full) - sampled:  ", collins_gelu_full_single_results["ϵ_samples"] ./ collins_gelu_full_results["ϵ_samples"])
# Out:
# gelu single vs multiple (small): [93.88171464650308, 90.78527332928644, 53.3933327158647, 28.558346331367044, 17.498988189041963, 10.795609104344425, 7.359464215183008, 4.989721495799975]
# gelu single vs multiple (full):  [32.48622279415809, 17.276735253525334, 11.273819807698763, 8.715953121752724, 7.063760764190039, 5.4149284083910345, 4.188896675504993, 3.2528017723756117]
#
# gelu single vs multiple (small) - sampled: [2.640541229320838, 4.582653888156421, 5.924423808335598, 4.510763580445359, 3.78943038724316, 2.7764468788484, 1.979898657404169, 1.9614081745878047]
# gelu single vs multiple (full) - sampled:  [2.702337981353897, 2.8864609070756457, 2.3947882752540552, 2.220377239968905, 1.4965315600895999, 1.8128012945414045, 1.8462125642917797, 1.7044205986952181]
